# %% [markdown]
# ---
# # **PyCaret for Classification**
# ---
# - It is a bundle of many Machine Learning algorithms.
# - Only three lines of code is required to compare 20 ML models.
# - Pycaret is available for:
#     - Classification
#     - Regression
#     - Clustering
#
# ---
#
# ### **Self learning resource**
# 1. Tutorial on Pycaret **<a href="https://pycaret.readthedocs.io/en/latest/tutorials.html"> Click Here</a>**
#
# 2. Documentation on Pycaret-Classification: **<a href="https://pycaret.readthedocs.io/en/latest/api/classification.html"> Click Here </a>**
#
# ---
#
# ### **In this tutorial we will learn:**
#
# - Getting Data
# - Setting up Environment
# - Create Model
# - Tune Model
# - Plot Model
# - Finalize Model
# - Predict Model
# - Save / Load Model
# ---

# %% [markdown]
# ### **(a) Install Pycaret**

# %%
# !pip install pycaret &> /dev/null
print ("Pycaret installed sucessfully!!")
# Out:
# Pycaret installed sucessfully!!

# %% [markdown]
# ### **(b) Get the version of the pycaret**

# %%
from pycaret.utils import version
version()
# Out:
# '2.3.3'

# %% [markdown]
# ---
# # **1. Classification: Basics**
# ---
# ### **1.1 Get the list of datasets available in pycaret (55)**

# %%
from pycaret.datasets import get_data
dataSets = get_data('index')
# Out:
#                              Dataset    Data Types  ... # Attributes Missing Values
# 0                            anomaly  Multivariate  ...           10              N
# 1                             france  Multivariate  ...            8              N
# 2                            germany  Multivariate  ...            8              N
# 3                               bank  Multivariate  ...           17              N
# 4                              blood  Multivariate  ...            5              N
# 5                             cancer  Multivariate  ...           10              N
# 6                             credit  Multivariate  ...           24              N
# 7                           diabetes  Multivariate  ...            9              N
# 8                    electrical_grid  Multivariate  ...           14              N
# 9                           employee  Multivariate  ...           10              N
# 10                             heart  Multivariate  ...           16              N
# 11                     heart_disease  Multivariate  ...           14              N
# 12                         hepatitis  Multivariate  ...           32              Y
# 13                            income  Multivariate  ...           14              Y
# 14                             juice  Multivariate  ...           15              N
# 15                               nba  Multivariate  ...           21              N
# 16                              wine  Multivariate  ...           13              N
# 17                         telescope  Multivariate  ...           11              N
# 18                           titanic  Multivariate  ...           11              Y
# 19  us_presidential_election_results  Multivariate  ...            7              N
# 20                             glass  Multivariate  ...           10              N
# 21                              iris  Multivariate  ...            5              N
# 22                             poker  Multivariate  ...           11              N
# 23                         questions  Multivariate  ...            4              N
# 24                         satellite  Multivariate  ...           37              N
# 25                               CTG  Multivariate  ...           40              Y
# 26                          asia_gdp  Multivariate  ...           11              N
# 27                         elections  Multivariate  ...           54              Y
# 28                          facebook  Multivariate  ...           12              N
# 29                               ipl  Multivariate  ...           25              N
# 30                         jewellery  Multivariate  ...            4              N
# 31                              mice  Multivariate  ...           82              Y
# 32                         migration  Multivariate  ...           12              N
# 33                           perfume  Multivariate  ...           29              N
# 34                           pokemon  Multivariate  ...           13              Y
# 35                        population  Multivariate  ...           56              Y
# 36                     public_health  Multivariate  ...           21              N
# 37                             seeds  Multivariate  ...            7              N
# 38                         wholesale  Multivariate  ...            8              N
# 39                            tweets          Text  ...            2              N
# 40                            amazon          Text  ...            2              N
# 41                              kiva          Text  ...            7              N
# 42                               spx          Text  ...            4              N
# 43                         wikipedia          Text  ...            3              N
# 44                        automobile  Multivariate  ...           26              Y
# 45                              bike  Multivariate  ...           15              N
# 46                            boston  Multivariate  ...           14              N
# 47                          concrete  Multivariate  ...            9              N
# 48                           diamond  Multivariate  ...            8              N
# 49                            energy  Multivariate  ...           10              N
# 50                            forest  Multivariate  ...           13              N
# 51                              gold  Multivariate  ...          121              N
# 52                             house  Multivariate  ...           81              Y
# 53                         insurance  Multivariate  ...            7              N
# 54                        parkinsons  Multivariate  ...           22              N
# 55                           traffic  Multivariate  ...            8              N
#
# [56 rows x 8 columns]

# %% [markdown]
# ---
# ### **1.2 Get the "diabetes" dataset**
# ---

# %%
diabetesDataSet = get_data("diabetes")    # SN is 7
# This is binary classification dataset. 
# The values in "Class variable" have two (binary) values.
# Out:
#    Number of times pregnant  ...  Class variable
# 0                         6  ...               1
# 1                         1  ...               0
# 2                         8  ...               1
# 3                         1  ...               0
# 4                         0  ...               1
#
# [5 rows x 9 columns]

# %% [markdown]
# ---
# ### **1.3 Download the "diabetes" dataset to local system**
# ---

# %%
diabetesDataSet.to_csv("diabetesDataSet.csv")
from google.colab import files
#files.download('diabetesDataSet.csv')            # Uncomment this line

# %% [markdown]
# ---
# ### **1.4 "Parameter setting"  for all classification models**
# ##### **Train/Test division, applying data pre-processing** {Sampling, Normalization, Transformation, PCA, Handaling of Outliers, Feature Selection}
# ---

# %%
from pycaret.classification import *  
s = setup(data=diabetesDataSet, target='Class variable', train_size=0.7, silent=True)
# Out:
#                                Description             Value
# 0                               session_id              2449
# 1                                   Target    Class variable
# 2                              Target Type            Binary
# 3                            Label Encoded        0: 0, 1: 1
# 4                            Original Data          (768, 9)
# 5                           Missing Values             False
# 6                         Numeric Features                 7
# 7                     Categorical Features                 1
# 8                         Ordinal Features             False
# 9                High Cardinality Features             False
# 10                 High Cardinality Method              None
# 11                   Transformed Train Set         (537, 22)
# 12                    Transformed Test Set         (231, 22)
# 13                      Shuffle Train-Test              True
# 14                     Stratify Train-Test             False
# 15                          Fold Generator   StratifiedKFold
# 16                             Fold Number                10
# 17                                CPU Jobs                -1
# 18                                 Use GPU             False
# 19                          Log Experiment             False
# 20                         Experiment Name  clf-default-name
# 21                                     USI              4795
# 22                         Imputation Type            simple
# 23          Iterative Imputation Iteration              None
# 24                         Numeric Imputer              mean
# 25      Iterative Imputation Numeric Model              None
# 26                     Categorical Imputer          constant
# 27  Iterative Imputation Categorical Model              None
# 28           Unknown Categoricals Handling    least_frequent
# 29                               Normalize             False
# 30                        Normalize Method              None
# 31                          Transformation             False
# 32                   Transformation Method              None
# 33                                     PCA             False
# 34                              PCA Method              None
# 35                          PCA Components              None
# 36                     Ignore Low Variance             False
# 37                     Combine Rare Levels             False
# 38                    Rare Level Threshold              None
# 39                         Numeric Binning             False
# 40                         Remove Outliers             False
# 41                      Outliers Threshold              None
# 42                Remove Multicollinearity             False
# 43             Multicollinearity Threshold              None
# 44             Remove Perfect Collinearity              True
# 45                              Clustering             False
# 46                    Clustering Iteration              None
# 47                     Polynomial Features             False
# 48                       Polynomial Degree              None
# 49                    Trignometry Features             False
# 50                    Polynomial Threshold              None
# 51                          Group Features             False
# 52                       Feature Selection             False
# 53                Feature Selection Method           classic
# 54            Features Selection Threshold              None
# 55                     Feature Interaction             False
# 56                           Feature Ratio             False
# 57                   Interaction Threshold              None
# 58                           Fix Imbalance             False
# 59                    Fix Imbalance Method             SMOTE

# %% [markdown]
# ---
# ### **1.5 "Run and Compare" the model performance**
# ---

# %%
cm = compare_models()

# %% [markdown]
# ---
# ### **1.6 "Three line of code" for model comparison for "Cancer" dataset**
# ---

# %%
from pycaret.datasets import get_data
from pycaret.classification import *

cancerDataSet = get_data("cancer")
# Out:
#    Class  age  menopause  tumor-size  ...  deg-malig  breast  breast-quad  irradiat
# 0      0    5          1           1  ...          1       3            1         1
# 1      0    5          4           4  ...         10       3            2         1
# 2      0    3          1           1  ...          2       3            1         1
# 3      0    6          8           8  ...          4       3            7         1
# 4      0    4          1           1  ...          1       3            1         1
#
# [5 rows x 10 columns]

# %%
from pycaret.datasets import get_data
from pycaret.classification import *

cancerDataSet = get_data("cancer")
s = setup(data = cancerDataSet, target='Class', silent=True)
cm = compare_models()
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# et                 Extra Trees Classifier    0.9687  0.9932  0.9585  0.9528
# lr                    Logistic Regression    0.9624  0.9919  0.9408  0.9521
# knn                K Neighbors Classifier    0.9603  0.9782  0.9228  0.9626
# svm                   SVM - Linear Kernel    0.9603  0.0000  0.9290  0.9576
# ridge                    Ridge Classifier    0.9603  0.0000  0.9290  0.9573
# gbc          Gradient Boosting Classifier    0.9582  0.9894  0.9404  0.9423
# lda          Linear Discriminant Analysis    0.9582  0.9877  0.9173  0.9631
# lightgbm  Light Gradient Boosting Machine    0.9582  0.9923  0.9346  0.9461
# nb                            Naive Bayes    0.9562  0.9795  0.9471  0.9315
# ada                  Ada Boost Classifier    0.9560  0.9877  0.9165  0.9578
# dt               Decision Tree Classifier    0.9498  0.9452  0.9290  0.9299
# qda       Quadratic Discriminant Analysis    0.8873  0.9102  0.9882  0.7691
#
#               F1   Kappa     MCC  TT (Sec)
# et        0.9552  0.9311  0.9316     0.705
# lr        0.9458  0.9170  0.9178     0.281
# knn       0.9412  0.9113  0.9129     0.121
# svm       0.9426  0.9123  0.9132     0.016
# ridge     0.9422  0.9121  0.9131     0.015
# gbc       0.9407  0.9084  0.9092     0.116
# lda       0.9388  0.9072  0.9087     0.023
# lightgbm  0.9395  0.9076  0.9085     0.089
# nb        0.9382  0.9043  0.9055     0.016
# ada       0.9356  0.9023  0.9039     0.107
# dt        0.9288  0.8901  0.8909     0.016
# qda       0.8631  0.7706  0.7905     0.261

# %% [markdown]
# ---
# ### **1.7 "Three line of code" for model comparison for "Heart Disease" dataset**
# ---

# %%
from pycaret.datasets import get_data
from pycaret.classification import *

heartDiseaseDataSet = get_data("heart_disease")
s = setup(data = heartDiseaseDataSet, target='Disease', silent=True)
cm = compare_models()

# %% [markdown]
# ---
# # **2. Classification: working with user dataset**
# ---
# ### **2.1 Uploading "user file" from user system**

# %%
from google.colab import files
# files.upload()                     # Uncomment this line
# Out:
#      <input type="file" id="files-808924e0-97c4-465d-adaf-ce534ac0bf09" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-808924e0-97c4-465d-adaf-ce534ac0bf09">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %% [markdown]
# ---
# ### **2.2 "Read" the uploaded file**
# ---

# %%
import pandas as pd
# myDataSet = pd.read_csv('BC7-LitCovid-Train.csv')        # Uncomment this line and replace the file name that read in above step
# myDataSet.head()                                             # Uncomment this line

# %% [markdown]
# ---
# ### **2.3 "Compare" the model performance**
# ---

# %%
from pycaret.classification import *

#s = setup(data = myDataSet, target='Cancer', silent=True)               # Uncomment this line
#cm = compare_models()                                                 # Uncomment this line

# %% [markdown]
# ---
# ### **2.4 "Three line of code" for model comparison for "user dataset**
#
# ##### Use it, while working on **"Anaconda/Jupyter notebook"** on local machine
# ---

# %%
from pycaret.classification import *
import pandas as pd

#myDataSet = pd.read_csv("myData.csv")                          # Uncomment this line
#s = setup(data = myDataSet, target='cancer', silent=True)      # Uncomment this line
#cm = compare_models()                                          # Uncomment this line

# %% [markdown]
# ---
# # **3. Classification: Apply "Data Preprocessing"**
# ---
#
# ### **3.1 Model performance using "Normalization"**

# %%
s = setup(data=diabetesDataSet, target='Class variable', normalize = True, normalize_method = 'zscore', silent=True)
cm = compare_models()

#normalize_method = {zscore, minmax, maxabs, robust}
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# lr                    Logistic Regression    0.7655  0.8110  0.5480  0.7074
# ridge                    Ridge Classifier    0.7618  0.0000  0.5363  0.7064
# lda          Linear Discriminant Analysis    0.7599  0.8058  0.5421  0.6982
# gbc          Gradient Boosting Classifier    0.7525  0.8296  0.5848  0.6618
# lightgbm  Light Gradient Boosting Machine    0.7506  0.7955  0.5959  0.6480
# rf               Random Forest Classifier    0.7488  0.8065  0.5196  0.6787
# ada                  Ada Boost Classifier    0.7486  0.7948  0.5792  0.6509
# svm                   SVM - Linear Kernel    0.7355  0.0000  0.5406  0.6482
# et                 Extra Trees Classifier    0.7339  0.7737  0.5038  0.6508
# dt               Decision Tree Classifier    0.7131  0.6902  0.6173  0.5773
# knn                K Neighbors Classifier    0.7114  0.7192  0.4819  0.5959
# nb                            Naive Bayes    0.6556  0.7366  0.0488  0.3893
# qda       Quadratic Discriminant Analysis    0.5610  0.6012  0.5532  0.3986
#
#               F1   Kappa     MCC  TT (Sec)
# lr        0.6095  0.4480  0.4606     0.024
# ridge     0.6036  0.4390  0.4514     0.013
# lda       0.6045  0.4373  0.4482     0.017
# gbc       0.6166  0.4357  0.4405     0.125
# lightgbm  0.6149  0.4325  0.4374     0.049
# rf        0.5830  0.4086  0.4195     0.518
# ada       0.6105  0.4263  0.4296     0.103
# svm       0.5755  0.3889  0.4015     0.015
# et        0.5575  0.3749  0.3865     0.464
# dt        0.5940  0.3736  0.3761     0.018
# knn       0.5241  0.3235  0.3315     0.118
# nb        0.0829  0.0229  0.0518     0.015
# qda       0.4362  0.1043  0.1200     0.016

# %% [markdown]
# ---
# ### **3.2 Model performance using "Feature Selection"**
# ---

# %%
s = setup(data=diabetesDataSet, target='Class variable', feature_selection = True, feature_selection_threshold = 0.9, silent=True)
cm = compare_models()
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# lightgbm  Light Gradient Boosting Machine    0.7898  0.8169  0.6398  0.7245
# gbc          Gradient Boosting Classifier    0.7822  0.8431  0.5845  0.7326
# rf               Random Forest Classifier    0.7821  0.8239  0.5789  0.7369
# ada                  Ada Boost Classifier    0.7692  0.7994  0.5971  0.6886
# lr                    Logistic Regression    0.7655  0.8194  0.5740  0.7007
# et                 Extra Trees Classifier    0.7599  0.7952  0.5193  0.7219
# ridge                    Ridge Classifier    0.7581  0.0000  0.5629  0.6855
# lda          Linear Discriminant Analysis    0.7562  0.8144  0.5579  0.6827
# knn                K Neighbors Classifier    0.7188  0.7482  0.5585  0.5941
# dt               Decision Tree Classifier    0.7041  0.6773  0.5944  0.5672
# nb                            Naive Bayes    0.6742  0.7367  0.2848  0.5522
# svm                   SVM - Linear Kernel    0.5866  0.0000  0.3588  0.3176
# qda       Quadratic Discriminant Analysis    0.5756  0.5608  0.4465  0.3987
#
#               F1   Kappa     MCC  TT (Sec)
# lightgbm  0.6751  0.5211  0.5266     0.047
# gbc       0.6446  0.4912  0.5017     0.120
# rf        0.6446  0.4910  0.5012     0.507
# ada       0.6365  0.4697  0.4742     0.107
# lr        0.6278  0.4588  0.4662     0.236
# et        0.5960  0.4319  0.4488     0.462
# ridge     0.6148  0.4407  0.4478     0.014
# lda       0.6104  0.4356  0.4430     0.018
# knn       0.5724  0.3645  0.3672     0.116
# dt        0.5775  0.3506  0.3530     0.018
# nb        0.3685  0.1812  0.2015     0.016
# svm       0.2793  0.0559  0.0612     0.018
# qda       0.3894  0.0926  0.0730     0.015

# %% [markdown]
# ---
# ### **3.3 Model performance using "Outlier Removal"**
# ---

# %%
s = setup(data=diabetesDataSet, target='Class variable', remove_outliers = True, outliers_threshold = 0.05, silent=True)
cm = compare_models()
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# lda          Linear Discriminant Analysis    0.7725  0.8212  0.5794  0.7124
# lr                    Logistic Regression    0.7667  0.8269  0.5732  0.6978
# ridge                    Ridge Classifier    0.7667  0.0000  0.5559  0.7118
# rf               Random Forest Classifier    0.7647  0.8227  0.5552  0.6961
# et                 Extra Trees Classifier    0.7490  0.8072  0.5150  0.6720
# gbc          Gradient Boosting Classifier    0.7451  0.8188  0.5676  0.6451
# lightgbm  Light Gradient Boosting Machine    0.7373  0.7890  0.5729  0.6282
# ada                  Ada Boost Classifier    0.7235  0.7859  0.5493  0.6047
# nb                            Naive Bayes    0.7216  0.7595  0.5088  0.6240
# knn                K Neighbors Classifier    0.7118  0.7453  0.5219  0.5975
# dt               Decision Tree Classifier    0.6961  0.6578  0.5376  0.5577
# qda       Quadratic Discriminant Analysis    0.5824  0.6239  0.6029  0.4780
# svm                   SVM - Linear Kernel    0.5588  0.0000  0.3863  0.2419
#
#               F1   Kappa     MCC  TT (Sec)
# lda       0.6298  0.4703  0.4817     0.016
# lr        0.6221  0.4574  0.4669     0.209
# ridge     0.6154  0.4532  0.4663     0.016
# rf        0.6148  0.4490  0.4571     0.515
# et        0.5767  0.4051  0.4156     0.462
# gbc       0.5964  0.4136  0.4201     0.117
# lightgbm  0.5939  0.4021  0.4065     0.047
# ada       0.5704  0.3691  0.3734     0.104
# nb        0.5506  0.3539  0.3646     0.016
# knn       0.5499  0.3413  0.3478     0.120
# dt        0.5445  0.3177  0.3198     0.017
# qda       0.4784  0.1676  0.1931     0.015
# svm       0.2625  0.0362  0.0287     0.018

# %% [markdown]
# ---
# ### **3.4 Model performance using "Transformation"**
# ---

# %%
s = setup(data=diabetesDataSet, target='Class variable', transformation = True, transformation_method = 'yeo-johnson', silent=True)
cm = compare_models()
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# lr                    Logistic Regression    0.7671  0.8109  0.5544  0.7219
# ridge                    Ridge Classifier    0.7578  0.0000  0.5333  0.6990
# lda          Linear Discriminant Analysis    0.7559  0.8056  0.5386  0.6872
# knn                K Neighbors Classifier    0.7412  0.7365  0.4798  0.6916
# rf               Random Forest Classifier    0.7410  0.7992  0.5222  0.6719
# ada                  Ada Boost Classifier    0.7356  0.7749  0.5240  0.6649
# gbc          Gradient Boosting Classifier    0.7336  0.8132  0.5228  0.6497
# et                 Extra Trees Classifier    0.7316  0.7516  0.4427  0.6828
# lightgbm  Light Gradient Boosting Machine    0.7168  0.7869  0.5228  0.6213
# svm                   SVM - Linear Kernel    0.6853  0.0000  0.4766  0.6037
# dt               Decision Tree Classifier    0.6833  0.6436  0.5129  0.5529
# nb                            Naive Bayes    0.6518  0.7119  0.0377  0.3100
# qda       Quadratic Discriminant Analysis    0.4937  0.5452  0.6673  0.3804
#
#               F1   Kappa     MCC  TT (Sec)
# lr        0.6172  0.4558  0.4708     0.025
# ridge     0.5971  0.4308  0.4437     0.014
# lda       0.5979  0.4286  0.4387     0.019
# knn       0.5558  0.3841  0.4027     0.117
# rf        0.5795  0.3980  0.4097     0.503
# ada       0.5766  0.3898  0.4009     0.102
# gbc       0.5727  0.3839  0.3932     0.123
# et        0.5307  0.3563  0.3759     0.465
# lightgbm  0.5626  0.3559  0.3627     0.049
# svm       0.4852  0.2779  0.3034     0.019
# dt        0.5290  0.2918  0.2943     0.016
# nb        0.0647  0.0217  0.0346     0.015
# qda       0.4632  0.0589  0.0819     0.017

# %% [markdown]
# ---
# ### **3.5 Model performance using "PCA"**
# ---

# %%
s = setup(data=diabetesDataSet, target='Class variable', pca = True, pca_method = 'linear', silent=True)
cm = compare_models()
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# ridge                    Ridge Classifier    0.7654  0.0000  0.5558  0.7233
# lda          Linear Discriminant Analysis    0.7654  0.8120  0.5558  0.7233
# lr                    Logistic Regression    0.7597  0.8124  0.5503  0.7141
# qda       Quadratic Discriminant Analysis    0.7356  0.7956  0.5137  0.6690
# nb                            Naive Bayes    0.7337  0.7923  0.5240  0.6579
# rf               Random Forest Classifier    0.7298  0.8078  0.5561  0.6370
# ada                  Ada Boost Classifier    0.7281  0.7952  0.5456  0.6320
# et                 Extra Trees Classifier    0.7262  0.8070  0.5292  0.6317
# gbc          Gradient Boosting Classifier    0.7226  0.8050  0.5298  0.6206
# knn                K Neighbors Classifier    0.7206  0.7519  0.5295  0.6259
# lightgbm  Light Gradient Boosting Machine    0.7186  0.7923  0.5392  0.6229
# dt               Decision Tree Classifier    0.7185  0.6837  0.5658  0.6084
# svm                   SVM - Linear Kernel    0.6630  0.0000  0.4547  0.5717
#
#               F1   Kappa     MCC  TT (Sec)
# ridge     0.6236  0.4579  0.4697     0.013
# lda       0.6236  0.4579  0.4697     0.015
# lr        0.6162  0.4459  0.4576     0.023
# qda       0.5765  0.3898  0.4001     0.016
# nb        0.5800  0.3891  0.3967     0.015
# rf        0.5911  0.3913  0.3951     0.511
# ada       0.5834  0.3840  0.3876     0.101
# et        0.5737  0.3751  0.3796     0.461
# gbc       0.5699  0.3682  0.3713     0.114
# knn       0.5712  0.3665  0.3712     0.117
# lightgbm  0.5737  0.3659  0.3709     0.050
# dt        0.5855  0.3731  0.3742     0.018
# svm       0.4820  0.2396  0.2556     0.017

# %% [markdown]
# ---
# ### **3.6 Model performance using "Outlier Removal" + "Normalization"**
# ---

# %%
s = setup(data=diabetesDataSet, target='Class variable', remove_outliers = True, outliers_threshold = 0.05, normalize = True, normalize_method = 'zscore', silent=True)
cm = compare_models()
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# lr                    Logistic Regression    0.7784  0.8321  0.5637  0.7261
# ridge                    Ridge Classifier    0.7745  0.0000  0.5346  0.7422
# rf               Random Forest Classifier    0.7706  0.8299  0.5686  0.7110
# lda          Linear Discriminant Analysis    0.7686  0.8288  0.5464  0.7173
# et                 Extra Trees Classifier    0.7588  0.7995  0.5170  0.7132
# ada                  Ada Boost Classifier    0.7529  0.7761  0.5451  0.6623
# gbc          Gradient Boosting Classifier    0.7529  0.8141  0.5631  0.6638
# knn                K Neighbors Classifier    0.7431  0.7510  0.5278  0.6470
# svm                   SVM - Linear Kernel    0.7255  0.0000  0.5578  0.6171
# lightgbm  Light Gradient Boosting Machine    0.7216  0.8003  0.5408  0.6192
# nb                            Naive Bayes    0.7000  0.7612  0.4650  0.5685
# dt               Decision Tree Classifier    0.7000  0.6653  0.5582  0.5679
# qda       Quadratic Discriminant Analysis    0.6373  0.4636  0.0971  0.1263
#
#               F1   Kappa     MCC  TT (Sec)
# lr        0.6274  0.4749  0.4871     0.023
# ridge     0.6115  0.4599  0.4782     0.015
# rf        0.6260  0.4640  0.4743     0.514
# lda       0.6089  0.4510  0.4663     0.016
# et        0.5870  0.4243  0.4427     0.462
# ada       0.5938  0.4200  0.4268     0.102
# gbc       0.5984  0.4241  0.4339     0.117
# knn       0.5781  0.3970  0.4032     0.116
# svm       0.5731  0.3746  0.3834     0.015
# lightgbm  0.5686  0.3662  0.3739     0.047
# nb        0.5049  0.2953  0.3015     0.014
# dt        0.5542  0.3307  0.3369     0.016
# qda       0.1015  0.0076  0.0036     0.015

# %% [markdown]
# ---
# ### **3.7 Model performance using "Outlier Removal" +  "Normalization" + "Transformation"**
# ---

# %%
s = setup(data=diabetesDataSet, target='Class variable', remove_outliers = True, outliers_threshold = 0.05, normalize = True, normalize_method = 'zscore', transformation = True, transformation_method = 'yeo-johnson', silent=True)
cm = compare_models()
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# lr                    Logistic Regression    0.7725  0.8244  0.5662  0.6968
# rf               Random Forest Classifier    0.7569  0.8188  0.5658  0.6548
# ridge                    Ridge Classifier    0.7549  0.0000  0.5364  0.6655
# gbc          Gradient Boosting Classifier    0.7549  0.8099  0.5779  0.6436
# lda          Linear Discriminant Analysis    0.7510  0.8197  0.5423  0.6549
# et                 Extra Trees Classifier    0.7510  0.7957  0.5074  0.6670
# knn                K Neighbors Classifier    0.7392  0.7687  0.5544  0.6172
# ada                  Ada Boost Classifier    0.7353  0.7880  0.5540  0.6053
# lightgbm  Light Gradient Boosting Machine    0.7275  0.7906  0.5721  0.5910
# svm                   SVM - Linear Kernel    0.7059  0.0000  0.5324  0.5863
# nb                            Naive Bayes    0.6804  0.7349  0.4592  0.5274
# dt               Decision Tree Classifier    0.6529  0.6054  0.4651  0.4779
# qda       Quadratic Discriminant Analysis    0.5882  0.5498  0.3621  0.3798
#
#               F1   Kappa     MCC  TT (Sec)
# lr        0.6216  0.4619  0.4693     0.022
# rf        0.6040  0.4307  0.4350     0.517
# ridge     0.5901  0.4188  0.4264     0.015
# gbc       0.6075  0.4306  0.4330     0.117
# lda       0.5885  0.4131  0.4202     0.016
# et        0.5708  0.4014  0.4123     0.462
# knn       0.5817  0.3937  0.3965     0.118
# ada       0.5766  0.3853  0.3873     0.100
# lightgbm  0.5793  0.3784  0.3800     0.048
# svm       0.5319  0.3261  0.3446     0.017
# nb        0.4843  0.2561  0.2615     0.015
# dt        0.4677  0.2118  0.2139     0.016
# qda       0.2965  0.0674  0.0806     0.015

# %% [markdown]
# ---
# ### **3.8 Explore more parameters of "setup()" on pycaret**
# ---
# - Explore setup() paramaeters in **Step 1.4**
# - **<a href="https://pycaret.readthedocs.io/en/latest/api/classification.html"> Click Here</a>** for more

# %% [markdown]
# ---
# # **4. Classification: More Operations**
# ---
# ### **4.1 Build a single model - "RandomForest"**

# %%
from pycaret.datasets import get_data
from pycaret.classification import *

diabetesDataSet = get_data("diabetes")
s = setup(data=diabetesDataSet, target='Class variable', silent=True)

rfModel = create_model('rf')
# Explore more parameters
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# 0       0.7593  0.8218  0.6667  0.6316  0.6486  0.4658  0.4661
# 1       0.8704  0.8989  0.7778  0.8235  0.8000  0.7042  0.7049
# 2       0.7593  0.8316  0.5263  0.7143  0.6061  0.4384  0.4490
# 3       0.7778  0.8391  0.4737  0.8182  0.6000  0.4609  0.4939
# 4       0.7407  0.8150  0.4737  0.6923  0.5625  0.3874  0.4014
# 5       0.7593  0.8353  0.4737  0.7500  0.5806  0.4236  0.4456
# 6       0.7593  0.8722  0.5263  0.7143  0.6061  0.4384  0.4490
# 7       0.6792  0.7413  0.5556  0.5263  0.5405  0.2944  0.2947
# 8       0.7170  0.8190  0.5556  0.5882  0.5714  0.3604  0.3607
# 9       0.8491  0.8730  0.8333  0.7500  0.7895  0.6723  0.6746
# Mean    0.7671  0.8347  0.5863  0.7009  0.6305  0.4646  0.4740
# SD      0.0535  0.0407  0.1230  0.0906  0.0867  0.1222  0.1209

# %% [markdown]
# ---
# ### **4.2 Other available classification models**
# ---
# -	'ada' -	Ada Boost Classifier
# -	'dt' -	Decision Tree Classifier
# -	'et' -	Extra Trees Classifier
# -	'gbc' -	Gradient Boosting Classifier
# -	'knn' -	K Neighbors Classifier
# -	'lightgbm' -	Light Gradient Boosting Machine
# -	'lda' -	Linear Discriminant Analysis
# -	'lr' -	Logistic Regression
# -	'nb' -	Naive Bayes
# -	'qda' -	Quadratic Discriminant Analysis
# -	'rf' -	Random Forest Classifier
# -	'ridge' -	Ridge Classifier
# -	'svm' -	SVM - Linear Kernel

# %% [markdown]
# ---
# ### **4.3 Explore more parameters of "create_model()" on pycaret**
# ---
#
# **<a href="https://pycaret.readthedocs.io/en/latest/api/classification.html"> Click Here</a>**

# %% [markdown]
# ---
# ### **4.4 Make prediction on the "new unseen dataset"**
# ---
# #### **Get the "new unseen dataset"**

# %%
# Select top 10 rows from diabetes dataset
newDataSet = get_data("diabetes").iloc[:10]
# Out:
#    Number of times pregnant  ...  Class variable
# 0                         6  ...               1
# 1                         1  ...               0
# 2                         8  ...               1
# 3                         1  ...               0
# 4                         0  ...               1
#
# [5 rows x 9 columns]

# %% [markdown]
# #### **Make prediction on "new unseen dataset"**

# %%
newPredictions = predict_model(rfModel, data = newDataSet)
newPredictions
# Out:
#    Number of times pregnant  ...  Score
# 0                         6  ...   0.86
# 1                         1  ...   0.93
# 2                         8  ...   0.84
# 3                         1  ...   1.00
# 4                         0  ...   0.87
# 5                         5  ...   0.98
# 6                         3  ...   0.66
# 7                        10  ...   0.53
# 8                         2  ...   0.90
# 9                         8  ...   0.64
#
# [10 rows x 11 columns]

# %% [markdown]
# ---
# ### **4.5 "Save" the prediction results to csv**
# ---

# %%
newPredictions.to_csv("NewPredictions.csv")
print("Result saved in NewPredictions.csv")
# Out:
# Result saved in NewPredictions.csv

# %% [markdown]
# ---
# ### **4.6 Download the "result file" to user local system**
# ---

# %%
from google.colab import files
# files.download('NewPredictions.csv')      # Uncomment this line

# %% [markdown]
# ---
# ### **4.7 "Save" the trained model**
# ---

# %%
sm = save_model(rfModel, 'rfModelFile')
# Out:
# Transformation Pipeline and Model Successfully Saved

# %% [markdown]
# ---
# ### **4.8 Download the "trained model file" to user local system**
# ---

# %%
from google.colab import files
#files.download('rfModelFile.pkl')           # Uncomment this line

# %% [markdown]
# ---
# ### **4.9  "Upload the trained model" --> "Load the model"  --> "Make the prediction" on "new unseen dataset"**
# ---
# ### **4.9.1 Upload the  "Trained Model"**

# %%
from google.colab import files
#files.upload()                    # Uncomment this line

# %% [markdown]
# ---
# ### **4.9.2 Load the "Model"**
# ---

# %%
#rfModel = load_model('rfModelFile (1)')        # Uncomment this line

# %% [markdown]
# ---
# ### **4.9.3 Make the prediction on "new unseen dataset"**
# ---

# %%
newPredictions = predict_model(rfModel, data = newDataSet)
newPredictions
# Out:
#    Number of times pregnant  ...  Score
# 0                         6  ...   0.86
# 1                         1  ...   0.93
# 2                         8  ...   0.84
# 3                         1  ...   1.00
# 4                         0  ...   0.87
# 5                         5  ...   0.98
# 6                         3  ...   0.66
# 7                        10  ...   0.53
# 8                         2  ...   0.90
# 9                         8  ...   0.64
#
# [10 rows x 11 columns]

# %% [markdown]
# ---
# # **5. Plot the trained model**
# ---
# **Following parameters can be plot for a trained model**
# *   Area Under the Curve         - 'auc'
# *   Discrimination Threshold     - 'threshold'
# *   Precision Recall Curve       - 'pr'
# *   Confusion Matrix             - 'confusion_matrix'
# *   Class Prediction Error       - 'error'
# *   Classification Report        - 'class_report'
# *   Decision Boundary            - 'boundary'
# *   Recursive Feat. Selection    - 'rfe'
# *   Learning Curve               - 'learning'
# *   Manifold Learning            - 'manifold'
# *   Calibration Curve            - 'calibration'
# *   Validation Curve             - 'vc'
# *   Dimension Learning           - 'dimension'
# *   Feature Importance           - 'feature'
# *   Model Hyperparameter         - 'parameter'

# %% [markdown]
# ---
# ### **5.1 Create RandomForest model or any other model**
# ---

# %%
rfModel = create_model('rf')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# 0       0.7593  0.8218  0.6667  0.6316  0.6486  0.4658  0.4661
# 1       0.8704  0.8989  0.7778  0.8235  0.8000  0.7042  0.7049
# 2       0.7593  0.8316  0.5263  0.7143  0.6061  0.4384  0.4490
# 3       0.7778  0.8391  0.4737  0.8182  0.6000  0.4609  0.4939
# 4       0.7407  0.8150  0.4737  0.6923  0.5625  0.3874  0.4014
# 5       0.7593  0.8353  0.4737  0.7500  0.5806  0.4236  0.4456
# 6       0.7593  0.8722  0.5263  0.7143  0.6061  0.4384  0.4490
# 7       0.6792  0.7413  0.5556  0.5263  0.5405  0.2944  0.2947
# 8       0.7170  0.8190  0.5556  0.5882  0.5714  0.3604  0.3607
# 9       0.8491  0.8730  0.8333  0.7500  0.7895  0.6723  0.6746
# Mean    0.7671  0.8347  0.5863  0.7009  0.6305  0.4646  0.4740
# SD      0.0535  0.0407  0.1230  0.0906  0.0867  0.1222  0.1209

# %% [markdown]
# ---
# ### **5.2 Create "Confusion Matrix"**
# ---

# %%
plot_model(rfModel, plot='confusion_matrix')

# %% [markdown]
# ---
# ### **5.3 Plot the "learning curve"**
# ---

# %%
plot_model(rfModel, plot='learning')

# %% [markdown]
# ---
# ### **5.4 Plot the "AUC Curve" (Area Under the Curve)**
# ---

# %%
plot_model(rfModel, plot='auc')

# %% [markdown]
# ---
# ### **5.5 Plot the "Decision Boundary"**
# ---

# %%
plot_model(rfModel, plot='boundary')

# %% [markdown]
# ---
# ### **5.6 Get the model "parameters"**
# ---

# %%
plot_model(rfModel, plot='parameter')

# %% [markdown]
# ---
# ### **5.7 Explore the more parameters of "plot_model()" on pycaret**
# ---
# **<a href="https://pycaret.readthedocs.io/en/latest/api/classification.html"> Click Here </a>**

# %% [markdown]
# ---
# # **6. Feature Importance**
# ---
# ### **6.1 Feature Importance using "Random Forest"**

# %%
rfModel = create_model('rf', verbose=False)
plot_model(rfModel, plot='feature')

# %% [markdown]
# ---
# ### **6.2 Feature Importance using "Extra Trees Regressor"**
# ---

# %%
etModel = create_model('et', verbose=False)
plot_model(etModel, plot='feature')

# %% [markdown]
# ---
# ### **6.3 Feature Importance using "Decision Tree"**
# ---

# %%
dtModel = create_model('dt', verbose=False)
plot_model(dtModel, plot='feature')

# %% [markdown]
# ---
# # **7. Tune/Optimize the model performance**
# ---
# ### **7.1 Train "Decision Tree" with default parameters**

# %%
dtModel = create_model('dt')

# %% [markdown]
# #### **Get the "parameters" of Decision Tree**

# %%
plot_model(dtModel, plot='parameter')

# %% [markdown]
# ---
# ### **7.2 Tune "Decision Tree" model**
# ---

# %%
dtModelTuned = tune_model(dtModel, n_iter=10)

# %% [markdown]
# #### **Get the "tuned parameters" of Decision Tree**

# %%
plot_model(dtModelTuned, plot='parameter')

# %% [markdown]
# ---
# ### **7.3 Explore more parameters of "tune_model()" on pycaret**
# ---
# **<a href="https://pycaret.readthedocs.io/en/latest/api/classification.html"> Click Here </a>**

# %% [markdown]
# ---
# # **8. Deploy the model on AWS**
# ---
# **<a href="https://pycaret.readthedocs.io/en/latest/api/classification.html">Click Here</a>**
